# %%
# %matplotlib notebook

# %%
# Dependencies
import os
import matplotlib.pyplot as plt
import pandas as pd
import csv
import numpy as np
from scipy.stats import sem, linregress

# %%
csv_path = ("../Transformed_data/CombinedDF.csv")
starter_df = pd.read_csv(csv_path, engine='python')
#book_list = book_list.reset_index(drop = True)
#book_list.drop(columns = ['Unnamed: 0'])
books_and_movies_list = starter_df
coltodrop = ['Movie Revenue', 'Book Title', 'Average Votes', 'Unnamed: 0']
books_and_movies_list = books_and_movies_list.drop(coltodrop, axis = 1)
books_and_movies_list.dropna(inplace = True)
books_and_movies_list = books_and_movies_list.loc[books_and_movies_list['Book Rating'] != 0]
books_and_movies_list.head()
# Out:
#    Movie Rating                               Title  Book Rating
# 0           7.8     around the world in eighty days         3.92
# 1           5.9                      body snatchers         3.89
# 2           7.9                        frankenstein         3.77
# 3           7.7                   the invisible man         3.85
# 4           5.8  journey to the center of the earth         3.85

# %%
plt.figure(1)
plt.scatter(books_and_movies_list['Book Rating'], books_and_movies_list['Movie Rating'], marker='o', linewidth=4, 
            linestyle='solid', color='blue', alpha=1)
# Adding a trendline
x=books_and_movies_list['Book Rating']
y=books_and_movies_list['Movie Rating']
slope, _, r_value, p_value, _ = linregress(x,y)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
# the line equation:
plt.text(1.2, 8.5, f"y = {z[0]:.4f}x + {z[1]:.4f}")
plt.text(1.2, 9, f"r\N{SUPERSCRIPT TWO} = {r_value**2:.3f}")
plt.text(1.2, 9.5, f"p-value = {p_value:.2e}")
plt.title('Adapted science fiction books ratings and corresponding film ratings')
plt.xlabel('Book Rating')
plt.axis(xmin=0, xmax=5)
plt.axis(ymin=0, ymax=10)
plt.ylabel('Movie Rating')
plt.grid()
plt.gcf().set_size_inches(8, 6)
plt.rcParams.update({'font.size': 10})
plt.savefig("../Plots/Books vs Movies Ratings.png", bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
revenue_vs_book = starter_df
coltodrop = ['Movie Rating', 'Book Title', 'Average Votes', 'Unnamed: 0']
revenue_vs_book = revenue_vs_book.drop(coltodrop, axis = 1)
revenue_vs_book.dropna(inplace = True)
revenue_vs_book = revenue_vs_book.loc[revenue_vs_book['Book Rating'] != 0]
revenue_vs_book.head()
# Out:
#     Movie Revenue                               Title  Book Rating
# 4     101653320.0  journey to the center of the earth         3.85
# 7     178094583.0                  planet of the apes         3.93
# 12     67128202.0                      witch mountain         3.88
# 24     20636742.0                        annihilation         3.67
# 25      4563873.0                      atlas shrugged         3.45

# %%
plt.figure(2)
plt.scatter(revenue_vs_book['Book Rating'], revenue_vs_book['Movie Revenue'], marker='o', linewidth=4, 
            linestyle='solid', color='blue', alpha=1)
# Adding a trendline
x=revenue_vs_book['Book Rating']
y=revenue_vs_book['Movie Revenue']
slope, _, r_value, p_value, _ = linregress(x,y)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
# the line equation:
plt.text(1.2, 300000000, f"y = {z[0]:.4f}x + {z[1]:.4f}")
plt.text(1.2, 325000000, f"r\N{SUPERSCRIPT TWO} = {r_value**2:.3f}")
plt.text(1.2, 350000000, f"p-value = {p_value:.2e}")
plt.title('Book ratings from adapted science fiction films and corresponding revenue from adapted film')
plt.xlabel('Book Rating')
plt.axis(xmin=0, xmax=5)
#plt.axis(ymin=0, ymax=10)
plt.ylabel('Movie Revenue')
plt.grid()
plt.gcf().set_size_inches(8, 6)
plt.rcParams.update({'font.size': 10})
plt.savefig("../Plots/Books Ratings vs Movies Revenues.png", bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
revenue_vs_movie = starter_df
coltodrop = ['Book Rating', 'Book Title', 'Average Votes', 'Unnamed: 0']
revenue_vs_movie = revenue_vs_movie.drop(coltodrop, axis = 1)
revenue_vs_movie.dropna(inplace = True)
revenue_vs_movie = revenue_vs_movie.loc[revenue_vs_movie['Movie Rating'] != 0]
revenue_vs_movie.head()
# Out:
#     Movie Rating  Movie Revenue                               Title
# 4            5.8    101653320.0  journey to the center of the earth
# 7            5.7    178094583.0                  planet of the apes
# 12           5.7     67128202.0                      witch mountain
# 24           6.9     20636742.0                        annihilation
# 25           5.7      4563873.0                      atlas shrugged

# %%
plt.figure(3)
plt.scatter(revenue_vs_movie['Movie Rating'], revenue_vs_movie['Movie Revenue'], marker='o', linewidth=4, 
            linestyle='solid', color='blue', alpha=1)
# Adding a trendline
x=revenue_vs_movie['Movie Rating']
y=revenue_vs_movie['Movie Revenue']
slope, _, r_value, p_value, _ = linregress(x,y)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
# the line equation:
plt.text(1.2, 350000000, f"y = {z[0]:.4f}x + {z[1]:.4f}")
plt.text(1.2, 375000000, f"r\N{SUPERSCRIPT TWO} = {r_value**2:.3f}")
plt.text(1.2, 400000000, f"p-value = {p_value:.2e}")
plt.title('Film ratings adapted from science fiction novels and their corresponding revenue')
plt.xlabel('Movie Rating')
plt.axis(xmin=0, xmax=10)
#plt.axis(ymin=0, ymax=10)
plt.ylabel('Movie Revenue')
plt.grid()
plt.gcf().set_size_inches(8, 6)
plt.rcParams.update({'font.size': 10})
plt.savefig("../Plots/Movies Ratings vs Movies Revenues.png", bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
