# %%
# The purpose of this code is to merge our scrapped GoodReads results 
# with Kaggle's GoodReads data, and compare how much the ratings have changed

import pandas as pd
import numpy as np
import re
from difflib import SequenceMatcher
import time
import matplotlib.pyplot as plt

# %%
# Load Kaggle dataset of book ratings
# Downloaded from: https://www.kaggle.com/gnanesh/goodreads-book-reviews
# NOTE THAT THIS DATASET IS NOT IN THE REPO AS IT IS OVER 304MB 
# AND THERE ARE TERMS TO AGREE ON KAGGLE TO WORK ON THIS DATASET

kaggle_book_reviews = pd.read_csv('../input_csv/br.csv', sep=',', encoding='utf8', engine='python', error_bad_lines=False)
kaggle_book_reviews.shape
# Out:
# Skipping line 312075: unexpected end of data
# (312073, 9)

# %%
# FYI: only one line gave problems in reading the file in

kaggle_book_reviews.head()
# Out:
#    bookID                                              title  \
# 0       9  Unauthorized Harry Potter Book Seven News: "Ha...
# 1       8  Harry Potter Boxed Set, Books 1-5 (Harry Potte...
# 2       3              Harry Potter and the Sorcerer's Stone
# 3       1  Harry Potter and the Half-Blood Prince (Harry ...
# 4       2  Harry Potter and the Order of the Phoenix (Har...
#
#                    author  rating  ratingsCount  reviewsCount  \
# 0  W. Frederick Zimmerman    3.73            22             1
# 1            J.K. Rowling    4.77         34107           156
# 2            J.K. Rowling    4.44       4911929         77741
# 3            J.K. Rowling    4.54       1810404         28053
# 4            J.K. Rowling    4.47       1862749         29308
#
#             reviewerName  reviewerRatings  \
# 0              Charles G              3.0
# 1  ✿Katherine Elizabeth✿              5.0
# 2                   Lora              5.0
# 3      Cait (Paper Fury)              5.0
# 4  Diane ϟ [ Lestrange ]              5.0
#
#                                               review
# 0                                                NaN
# 1                                                NaN
# 2  I'm going to keep this brief since there isn't...
# 3  "Read Harry Potter!" they said. "It'll be fun!...
# 4                                                NaN

# %%
# Drop unnecessary columns:
kaggle_book_reviews = kaggle_book_reviews[['title','author','rating','ratingsCount']]
kaggle_book_reviews.head()
# Out:
#                                                title                  author  \
# 0  Unauthorized Harry Potter Book Seven News: "Ha...  W. Frederick Zimmerman
# 1  Harry Potter Boxed Set, Books 1-5 (Harry Potte...            J.K. Rowling
# 2              Harry Potter and the Sorcerer's Stone            J.K. Rowling
# 3  Harry Potter and the Half-Blood Prince (Harry ...            J.K. Rowling
# 4  Harry Potter and the Order of the Phoenix (Har...            J.K. Rowling
#
#    rating  ratingsCount
# 0    3.73            22
# 1    4.77         34107
# 2    4.44       4911929
# 3    4.54       1810404
# 4    4.47       1862749

# %%
# Let's clean up the titles a bit as well
kaggle_book_reviews['title'] = [re.split(r'\s{2,}', s.strip())[0] for s in list(kaggle_book_reviews['title'])]
kaggle_book_reviews.head()
# Out:
#                                                title                  author  \
# 0  Unauthorized Harry Potter Book Seven News: "Ha...  W. Frederick Zimmerman
# 1  Harry Potter Boxed Set, Books 1-5 (Harry Potte...            J.K. Rowling
# 2              Harry Potter and the Sorcerer's Stone            J.K. Rowling
# 3  Harry Potter and the Half-Blood Prince (Harry ...            J.K. Rowling
# 4  Harry Potter and the Order of the Phoenix (Har...            J.K. Rowling
#
#    rating  ratingsCount
# 0    3.73            22
# 1    4.77         34107
# 2    4.44       4911929
# 3    4.54       1810404
# 4    4.47       1862749

# %%
# There are lots of duplicate titles; let's clean them up!

kaggle_book_reviews = kaggle_book_reviews.sort_values(['title']) # have to use deprecated sort_values() here b/c of my version of Python (instead of sort())
kaggle_book_reviews.drop_duplicates(subset="title", inplace=True)
print(kaggle_book_reviews.shape)
kaggle_book_reviews.head()
# Out:
# (282731, 4)
#                                                     title  \
# 239779                                       !Vaya! Nuevo
# 156325  ""All the World Is Here!"": The Black Presence...
# 202567  ""City of the Century"": A History of Gary, In...
# 64623   ""We Only Come Here to Struggle"": Stories fro...
# 257999  "...das heilige Evangelion in Schwang zu bring...
#
#                          author  rating  ratingsCount
# 239779           Michael Buckby    0.00             0
# 156325  Christopher Robert Reed    2.67             3
# 202567            James B. Lane    3.89             9
# 64623           Berida Ndambuki    3.17             6
# 257999            Reiner Nägele    0.00             0

# %%
# Certainly requires more work to clean the titles up... 
# Will leave it for another day...

# %%
# Load Purnima's Wikipedia-scrapped list of movies adapted from science fiction books:
adapted_books = pd.read_csv('../input_csv/merged_list.csv', engine='python', encoding='utf8').drop(['Unnamed: 0'],axis=1)
print('There are '+ str(adapted_books.shape[0]) + ' films adapted from books')
adapted_books.head()
# Out:
# There are 199 films adapted from books
#                                  movie  \
# 0      Around the World in Eighty Days
# 1                      Body Snatchers
# 2                         Frankenstein
# 3                    The Invisible Man
# 4   Journey to the Center of the Earth
#
#                                                books  rating  average_votes
# 0  Around the World in Eighty Days (Extraordinary...    3.92         156130
# 1                     Invasion of the Body Snatchers    3.89          17377
# 2                                       Frankenstein    3.77         992321
# 3                                      Invisible Man    3.85         139972
# 4  Journey to the Center of the Earth (Extraordin...    3.85         126382

# %%
# cleaning up trailing white spaces and strings not part of the actual title (these are easily
# found as there are usually more than 2 whitespaces after the title)
adapted_books_list = [re.split(r'\s{2,}', s.strip())[0] for s in list(adapted_books['books'])]
adapted_books_list
# Out:
# ['Around the World in Eighty Days (Extraordinary Voyages, #11)',
#  'Invasion of the Body Snatchers',
#  'Frankenstein',
#  'Invisible Man',
#  'Journey to the Center of the Earth (Extraordinary Voyages, #3)',
#  'The Mysterious Island (Extraordinary Voyages, #12)',
#  'Nineteen Eighty-Four',
#  'Planet of the Apes',
#  'Twenty Thousand Leagues Under the Sea (Extraordinary Voyages, #6)',
#  'Retirement Village of the Damned',
#  'The War of the Worlds',
#  'Escape to Witch Mountain',
#  'The 5th Wave (The 5th Wave, #1)',
#  'The 27th Day',
#  '2010: The Year We Make Contact',
#  '20,000 Leagues Under the Sea',
#  'Action Replayy',
#  'Aelita',
#  'Altered States (Altered States, #0.5)',
#  'The Amphibian',
#  'Andromeda Nebula',
#  'The Andromeda Strain',
#  'Anna to the Infinite Power',
#  'Annihilation (Southern Reach, #1)',
#  'Atlas Shrugged (SparkNotes Literature Guides)',
#  'Atlas Shrugged, Part A',
#  'Atragon',
#  'Babylon A.D.',
#  'Battle Royale',
#  'Battlefield Earth: A Saga of the Year 3000',
#  'Blademage Beastmaster (Blademage, #1)',
#  'The Bicentennial Man and Other Stories',
#  'Bill, the Galactic Hero (Bill, the Galactic Hero, #1)',
#  'Bird Box',
#  'Blueprints',
#  'The Boys from Brazil',
#  'Brave New World',
#  "Buddha's Little Finger",
#  "Dawn's Early Light (Williamsburg #1)",
#  'Carnosaur',
#  'Cell',
#  'The Knife of Never Letting Go (Chaos Walking, #1)',
#  'The Library at Mount Char',
#  'Charodei ponevole',
#  'The Children of Men',
#  'Revenger, Vol. 1: Children of the Damned',
#  'The Circle',
#  'The City of Ember (Book of Ember, #1)',
#  'A Clockwork Orange',
#  'Cloud Atlas',
#  'Cocoon',
#  'Films Directed by Joseph Sargent (Study Guide): Jaws: The Revenge, the Taking of Pelham One Two Three, Colossus: The Forbin Project, Nightmares',
#  'Congo',
#  'The Futurological Congress: From the Memoirs of Ijon Tichy',
#  'The Conquest of Space',
#  'Focus On: Search for Extraterrestrial Intelligence: Fermi Paradox, Kardashev Scale, Wow! Signal, Dyson Sphere, Contact (1997 American film), Voyager Golden ... Pioneer Plaque, Arecibo Message, etc.',
#  'Countdown',
#  'Damnation Alley',
#  'Dandelion Wine',
#  'Dark Planet Falling (Dark Planet Warriors, #2)',
#  'The Darkest Minds (The Darkest Minds, #1)',
#  'The Day of the Dolphin',
#  'The Day of the Triffids',
#  'Lietuvos Roko Atlik Jai: Andrius Mamontovas, Days of Eclipse, Antis, LT United, Atalyja, Amberlife, Gyvai, Poliarizuoti Stiklai',
#  'The Dead Mountaineer Hotel',
#  'Homeward Bound (Deathlands, #5)',
#  'The Deluge',
#  'Demon Seed',
#  'Destination Moon (Tintin, #16)',
#  'Divergent (Divergent, #1)',
#  'The World of Divergent: The Path to Allegiant (Divergent, #2.5)',
#  'Divergent Series (Divergent, Insurgent, Allegiant): by Veronica Roth -- Sidekick',
#  'Nightmares and Dreamscapes',
#  'Dune (Dune Chronicles, #1)',
#  'Eagle Eye (Shadows in the Dark, #6)',
#  'Earth vs. the Flying Saucers',
#  'The Edge of Tomorrow',
#  'The End of Eternity',
#  "Ender's Game (Ender's Saga, #1)",
#  'Escape to Witch Mountain',
#  'Twenty Thousand Leagues Under the Sea',
#  'The Face of Another',
#  'Fahrenheit 451',
#  'Fantastic Planet',
#  'Fatherland',
#  'The Final Programme',
#  'Four-Sided Triangle',
#  'Freejack',
#  'The Girl Who Leapt Through Time',
#  'The Girl With All the Gifts (The Girl With All the Gifts, #1)',
#  'The Giver',
#  'Gladiator (Galactic Gladiators, #1)',
#  'Goldengirl',
#  'Tarnsman of Gor (Gor #1)',
#  'The Guest from the Future: Anna Akhmatova and Isaiah Berlin',
#  "The Handmaid's Tale",
#  'Hard to Be a God',
#  'Harrison Bergeron',
#  'The High Crusade',
#  "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy, #1)",
#  'The Host (The Host, #1)',
#  'The Hunger Games Series (A BookCaps Study Guide)',
#  'I Am Legend',
#  'I Am Number Four (Lorien Legacies, #1)',
#  'I Am Legend',
#  'In Search of the Castaways; or the Children of Captain Grant (Extraordinary Voyages, #5)',
#  'The Incredible Shrinking Man',
#  'The Incredible Shrinking Woman',
#  'The Art of the Iron Giant - CANCELLED',
#  'The Iron Heel',
#  'Island At The Top Of The World',
#  'Jumper (Jumper, #1)',
#  'Jurassic Park (Jurassic Park, #1)',
#  'K-Pax (K-Pax, #1)',
#  'The Land That Time Forgot (Caspak, #1)',
#  'The Last Man on Earth (The Graysons, #1)',
#  'The Lathe of Heaven',
#  'The Lathe of Heaven',
#  'Hippocrates Lifeforce: Superior Health and Longevity',
#  "Logan's Run (Logan, #1)",
#  'The Lost World (Jurassic Park #2)',
#  'Le Maître Du Temps',
#  'The Man Who Fell to Earth',
#  'Marooned in Realtime (Across Realtime, #2)',
#  'The Martian',
#  'The Maze Runner (The Maze Runner, #1)',
#  'Maze Runner: The Death Cure: The Official Graphic Novel Prelude',
#  'Maze Runner: The Scorch Trials: The Official Graphic Novel Prelude',
#  'Meg (MEG, #1)',
#  'Memoirs of an Invisible Man',
#  'Dark Metropolis (Dark Metropolis, #1)',
#  'The Girl with the Dragon Tattoo (Millennium, #1)',
#  'The Extended Mission of Stardust Four Zero',
#  'Mortal Engines',
#  'Mr. Murder',
#  'Never Let Me Go',
#  'Night Of The Big Heat',
#  'The Hidden Oasis',
#  'Omega, the Man',
#  'Tarzan And The Silver Globe ..',
#  'Paprika',
#  'Parasite Eve',
#  'The People That Time Forgot (Caspak, #2)',
#  'The Postman',
#  'The Power',
#  'The Prestige',
#  'A Princess of Mars (Barsoom, #1)',
#  'Project X',
#  'Julius Caesar: The Pursuit of Power',
#  'The Quiet Earth',
#  'Radio Free Albemuth',
#  'Ready Player One (Ready Player One, #1)',
#  'Return from Witch Mountain',
#  'The Gods of Riverworld (Riverworld, #5)',
#  'The Gods of Riverworld (Riverworld, #5)',
#  'The Road',
#  'The Running Man',
#  'The Satan Bug',
#  'A Scanner Darkly',
#  'Skullduggery',
#  'Slaughterhouse-Five',
#  'Solar Dance: Genius, Forgery and the Crisis of Truth in the Modern Age',
#  'Solaris',
#  'Sherman: Soldier, Realist, American',
#  'Solo',
#  'Somewhere In Time',
#  'La soupe aux choux',
#  'Soylent Green',
#  'Stalking Jack the Ripper (Stalking Jack the Ripper, #1)',
#  'Starship Troopers',
#  "Articles on Films Based on IRA Levin's Works, Including: The Boys from Brazil (Film), the Stepford Wives (2004 Film), a Kiss Before Dying (1991 Film), the Stepford Wives (1975 Film), Rosemary's Baby (Film), the Stepford Children",
#  'Stepford Husbands',
#  'The Stepford Wives',
#  'The Strange World of Planet X',
#  'Subterranean',
#  'Damned (Damned, #1)',
#  'Sweet Thing (Sweet Thing, #1)',
#  'The Prisoners of the Thirteenth Floor',
#  'This Island Earth',
#  'The Three-Body Problem (Remembrance of Earth’s Past #1)',
#  'The Time Machine',
#  "The Time Traveler's Wife",
#  'Timeline',
#  'Timescape',
#  'À ton image',
#  'Moonwalk: The First Trip to the Moon',
#  'The Tunnel Under the World',
#  'The Ugly Swans',
#  'Retirement Village of the Damned',
#  'The Village Schoolmaster',
#  'Vinyl (Vinyl #1)',
#  'The Hot Zone: The Terrifying True Story of the Origins of the Ebola Virus',
#  'All the Light We Cannot See',
#  'When Worlds Collide (When Worlds Collide, #1)',
#  'Woman of the Sun, Woman of the Moon',
#  "Ghost in the Wires: My Adventures as the World's Most Wanted Hacker",
#  'The World, the Flesh and the Devil',
#  'A Wrinkle in Time (Time Quintet, #1)',
#  'Z for Zachariah']

# %%
# Testing

# As one can see, the strings of titles may be hard to match against; 
# we need to use the SequenceMatcher in difflib library to get a similarity ratio:

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

def mostsimilar(sentence, alist):
    scores = [similar(sentence, sentence_in_list) for sentence_in_list in alist]
    max_score = max(scores)
    result = pd.DataFrame({
        'row_index': [scores.index(max_score)]
        ,'max_score': [max_score]
        })
    return result

# Find the rows in Kaggle's dataframe (kaggle_book_reviews) 
# with the highest match for the scrapped movie-adapted sci-fi titles dataframe (adapted_books)

# Time how long it takes (approx) to search one title:
indexes_for_movies = pd.DataFrame()
kaggle_titles = list(kaggle_book_reviews['title'])
bookTitle = adapted_books['books'][0]
t0 = time.time()
#for bookTitle in list(adapted_books['books']):
indexes_for_movies = indexes_for_movies.append(mostsimilar(bookTitle, kaggle_titles))
t1 = time.time()
total_time = t1-t0

print(indexes_for_movies)
# Out:
#    max_score  row_index
# 0        1.0      20478

# %%
# Testing (cont'd)
bookTitle
# Out:
# 'Around the World in Eighty Days (Extraordinary Voyages, #11)'

# %%
# Testing (cont'd)
kaggle_book_reviews.iloc[indexes_for_movies['row_index'],0]
# Out:
# 52625    Around the World in Eighty Days (Extraordinary...
# Name: title, dtype: object

# %%
# Testing (cont'd)
print(total_time)
# Out:
# 73.00290131568909

# %%
# So ~4 hours to search all 199 book titles...
# Doable... but I am too impatient...
# We'll focus on exact title matches (see below)

# %%
exact_kaggle_matches = kaggle_book_reviews.loc[kaggle_book_reviews['title'].isin(adapted_books_list)]
print('Found ' + str(exact_kaggle_matches.shape[0]) + ' out of ' + str(len(adapted_books_list)) + ' adapted scifi book titles')
exact_kaggle_matches.head()
# Out:
# Found 81 out of 199 adapted scifi book titles
#                                        title                author  rating  \
# 292963          20,000 Leagues Under the Sea           Jules Verne    3.86
# 21963                     A Clockwork Orange       Anthony Burgess    3.98
# 198026      A Princess of Mars (Barsoom, #1)  Edgar Rice Burroughs    3.80
# 12799                       A Scanner Darkly        Philip K. Dick    4.04
# 147746  A Wrinkle in Time (Time Quintet, #1)     Madeleine L'Engle    4.04
#
#         ratingsCount
# 292963        151037
# 21963         460568
# 198026         43311
# 12799          62350
# 147746        663124

# %%
# Intersect the scrapped GoodReads ratings and Kaggle titles to see how the ratings differ between the two:
merged_df = pd.merge(exact_kaggle_matches, adapted_books, left_on='title', right_on='books', how='inner').drop_duplicates(subset='title')
print(merged_df.shape)
merged_df
# Out:
# (81, 8)
#                                                 title  \
# 0                        20,000 Leagues Under the Sea
# 1                                  A Clockwork Orange
# 2                    A Princess of Mars (Barsoom, #1)
# 3                                    A Scanner Darkly
# 4                A Wrinkle in Time (Time Quintet, #1)
# 5                                              Aelita
# 6                         All the Light We Cannot See
# 7                          Anna to the Infinite Power
# 8   Around the World in Eighty Days (Extraordinary...
# 9       Atlas Shrugged (SparkNotes Literature Guides)
# 10                                      Battle Royale
# 11         Battlefield Earth: A Saga of the Year 3000
# 12                                    Brave New World
# 13                             Buddha's Little Finger
# 14                                               Cell
# 15                                        Cloud Atlas
# 16                                              Congo
# 17                                          Countdown
# 18                                    Damnation Alley
# 19                                     Dandelion Wine
# 20                                         Demon Seed
# 21                     Destination Moon (Tintin, #16)
# 22                         Dune (Dune Chronicles, #1)
# 23                    Ender's Game (Ender's Saga, #1)
# 24                                     Fahrenheit 451
# 25                                         Fatherland
# 26                                       Frankenstein
# 27                    Homeward Bound (Deathlands, #5)
# 28                                        I Am Legend
# 30  In Search of the Castaways; or the Children of...
# ..                                                ...
# 52                                       Subterranean
# 53                               The Andromeda Strain
# 54             The Bicentennial Man and Other Stories
# 55                                The Children of Men
# 56              The City of Ember (Book of Ember, #1)
# 57                             The Day of the Dolphin
# 58                            The Day of the Triffids
# 59                               The Edge of Tomorrow
# 60                                The Face of Another
# 61                                          The Giver
# 62  The Guest from the Future: Anna Akhmatova and ...
# 63                                The Handmaid's Tale
# 64                                   The High Crusade
# 65  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 66  The Hot Zone: The Terrifying True Story of the...
# 67                                      The Iron Heel
# 68                                The Lathe of Heaven
# 70                          The Man Who Fell to Earth
# 71  The Mysterious Island (Extraordinary Voyages, ...
# 72                                        The Postman
# 73                                       The Prestige
# 74                                           The Road
# 75                                    The Running Man
# 76                                 The Stepford Wives
# 77                                   The Time Machine
# 78                           The Time Traveler's Wife
# 79                              The War of the Worlds
# 80                                           Timeline
# 81              Twenty Thousand Leagues Under the Sea
# 82                                    Z for Zachariah
#
#                           author  rating_x  ratingsCount  \
# 0                    Jules Verne      3.86        151037
# 1                Anthony Burgess      3.98        460568
# 2           Edgar Rice Burroughs      3.80         43311
# 3                 Philip K. Dick      4.04         62350
# 4              Madeleine L'Engle      4.04        663124
# 5   Aleksey Nikolayevich Tolstoy      3.66           785
# 6                  Anthony Doerr      4.31        569524
# 7                   Mildred Ames      3.91           517
# 8                    Jules Verne      3.91        142833
# 9                     SparkNotes      3.47            15
# 10                Koushun Takami      4.24         41787
# 11                L. Ron Hubbard      3.49         13985
# 12                 Aldous Huxley      3.97       1094510
# 13                Victor Pelevin      4.25          3299
# 14                  Stephen King      3.64        155456
# 15                David Mitchell      4.01        174208
# 16              Michael Crichton      3.56        135620
# 17                  Amitav Ghosh      3.73           372
# 18                 Roger Zelazny      3.55          3741
# 19                  Ray Bradbury      4.08         40774
# 20                   Dean Koontz      3.39         11762
# 21                         Hergé      4.16         10087
# 22                 Frank Herbert      4.19        533287
# 23              Orson Scott Card      4.30        884576
# 24                  Ray Bradbury      3.97       1195840
# 25               Robert   Harris      3.96         24119
# 26   Mary Wollstonecraft Shelley      3.76        897833
# 27                   James Axler      3.81           381
# 28                   Steve Niles      3.99          2025
# 30                   Jules Verne      4.07          8136
# ..                           ...       ...           ...
# 52                 Jill Bialosky      3.88            16
# 53              Michael Crichton      3.87        181022
# 54                  Isaac Asimov      4.06          9516
# 55                    P.D. James      3.69         32554
# 56                 Jeanne DuPrau      3.85        207039
# 57                  Robert Merle      3.84           655
# 58                  John Wyndham      4.00         66666
# 59                  Isaac Asimov      3.92           951
# 60                      Kōbō Abe      3.78          2318
# 61                    Lois Lowry      4.12       1355633
# 62                  György Dalos      3.88            17
# 63               Margaret Atwood      4.07        718542
# 64                 Poul Anderson      3.89          2796
# 65                 Douglas Adams      4.20       1016309
# 66             Richard   Preston      4.10         77437
# 67                   Jack London      3.74          5684
# 68             Ursula K. Le Guin      4.09         34783
# 70                  Walter Tevis      4.01          4188
# 71                   Jules Verne      4.08         34874
# 72                    David Brin      3.88         26516
# 73            Christopher Priest      3.88         14087
# 74               Cormac McCarthy      3.95        561606
# 75               Richard Bachman      3.81         69705
# 76                     Ira Levin      3.71         21084
# 77                    H.G. Wells      3.87        308714
# 78            Audrey Niffenegger      3.95       1322250
# 79                    H.G. Wells      3.80        184262
# 80              Michael Crichton      3.83        159978
# 81                   Jules Verne      3.86        150833
# 82             Robert C. O'Brien      3.64         11654
#
#                                     movie  \
# 0           20,000 Leagues Under the Sea
# 1                     A Clockwork Orange
# 2                        Princess of Mars
# 3                       A Scanner Darkly
# 4                     A Wrinkle in Time
# 5                                  Aelita
# 6                                    We
# 7              Anna to the Infinite Power
# 8         Around the World in Eighty Days
# 9                  Atlas Shrugged  series
# 10                         Battle Royale
# 11                     Battlefield Earth
# 12                      Brave New World
# 13                Buddha's Little Finger
# 14                                  Cell
# 15                           Cloud Atlas
# 16                                 Congo
# 17                            Countdown
# 18                       Damnation Alley
# 19                        Dandelion Wine
# 20                             Demon Seed
# 21                      Destination Moon
# 22                                  Dune
# 23                          Ender's Game
# 24                       Fahrenheit 451
# 25                           Fatherland
# 26                           Frankenstein
# 27             Deathlands: Homeward Bound
# 28                           I Am Legend
# 30            In Search of the Castaways
# ..                                    ...
# 52                      The Subterraneans
# 53                  The Andromeda Strain
# 54                      Bicentennial Man
# 55                        Children of Men
# 56                          City of Ember
# 57                 The Day of the Dolphin
# 58               The Day of the Triffids
# 59                       Edge of Tomorrow
# 60                   The Face of Another
# 61                             The Giver
# 62                  Guest from the Future
# 63                   The Handmaid's Tale
# 64                       The High Crusade
# 65  The Hitchhiker's Guide to the Galaxy
# 66                                Virus
# 67                         The Iron Heel
# 68                       Lathe of Heaven
# 70              The Man Who Fell to Earth
# 71                  The Mysterious Island
# 72                           The Postman
# 73                          The Prestige
# 74                             The Road
# 75                      The Running Man
# 76                   The Stepford Wives
# 77                     The Time Machine
# 78              The Time Traveler's Wife
# 79                  The War of the Worlds
# 80                             Timeline
# 81                                  F.P.1
# 82                       Z for Zachariah
#
#                                                 books  rating_y  average_votes
# 0                        20,000 Leagues Under the Sea      3.84           1779
# 1                                  A Clockwork Orange      3.99         517714
# 2                    A Princess of Mars (Barsoom, #1)      3.80          46302
# 3                                    A Scanner Darkly      4.03          72874
# 4                A Wrinkle in Time (Time Quintet, #1)      4.02         829770
# 5                                              Aelita      3.65            926
# 6                         All the Light We Cannot See      4.33         752045
# 7                          Anna to the Infinite Power      3.91            549
# 8   Around the World in Eighty Days (Extraordinary...      3.92         156130
# 9       Atlas Shrugged (SparkNotes Literature Guides)      3.45             20
# 10                                      Battle Royale      4.25          45979
# 11         Battlefield Earth: A Saga of the Year 3000      3.51          15360
# 12                                    Brave New World      3.98        1225092
# 13                             Buddha's Little Finger      4.26           4002
# 14                                               Cell      3.65         171139
# 15                                        Cloud Atlas      4.02         189801
# 16                                              Congo      3.58         144044
# 17                                          Countdown      3.72           1610
# 18                                    Damnation Alley      3.55           4046
# 19                                     Dandelion Wine      4.09          46040
# 20                                         Demon Seed      3.40          12703
# 21                     Destination Moon (Tintin, #16)      4.17          11087
# 22                         Dune (Dune Chronicles, #1)      4.21         597667
# 23                    Ender's Game (Ender's Saga, #1)      4.30         982524
# 24                                     Fahrenheit 451      3.98        1355170
# 25                                         Fatherland      3.97          28586
# 26                                       Frankenstein      3.77         992321
# 27                    Homeward Bound (Deathlands, #5)      3.83            406
# 28                                        I Am Legend      4.06          74747
# 30  In Search of the Castaways; or the Children of...      4.08           9197
# ..                                                ...       ...            ...
# 52                                       Subterranean      4.02          20610
# 53                               The Andromeda Strain      3.89         196563
# 54             The Bicentennial Man and Other Stories      4.08          10431
# 55                                The Children of Men      3.68          35227
# 56              The City of Ember (Book of Ember, #1)      3.86         220889
# 57                             The Day of the Dolphin      3.83            749
# 58                            The Day of the Triffids      4.01          75896
# 59                               The Edge of Tomorrow      3.94           1057
# 60                                The Face of Another      3.78           2717
# 61                                          The Giver      4.12        1485533
# 62  The Guest from the Future: Anna Akhmatova and ...      3.84             19
# 63                                The Handmaid's Tale      4.09         996490
# 64                                   The High Crusade      3.90           3121
# 65  The Hitchhiker's Guide to the Galaxy (Hitchhik...      4.22        1184113
# 66  The Hot Zone: The Terrifying True Story of the...      4.11          84477
# 67                                      The Iron Heel      3.75           6876
# 68                                The Lathe of Heaven      4.10          41770
# 70                          The Man Who Fell to Earth      4.03           5035
# 71  The Mysterious Island (Extraordinary Voyages, ...      4.10          38413
# 72                                        The Postman      3.88          28329
# 73                                       The Prestige      3.88          15622
# 74                                           The Road      3.96         622235
# 75                                    The Running Man      3.85          84096
# 76                                 The Stepford Wives      3.74          24476
# 77                                   The Time Machine      3.88         348597
# 78                           The Time Traveler's Wife      3.96        1421978
# 79                              The War of the Worlds      3.81         206345
# 80                                           Timeline      3.84         171624
# 81              Twenty Thousand Leagues Under the Sea      3.87         167478
# 82                                    Z for Zachariah      3.65          12705
#
# [81 rows x 8 columns]

# %%
kaggle_ratings = merged_df['rating_x']
recently_scrapped_ratings = merged_df['rating_y']
plt.scatter(recently_scrapped_ratings, kaggle_ratings)
plt.title('Kaggle vs more recently scrapped GoodReads user ratings')
plt.xlabel('Recently scrapped GoodReads ratings')
plt.ylabel('Kaggle ratings')
plt.savefig("../Plots/kaggle_vs_our_ratings.png", bbox_inches='tight')
plt.show()

# %%
# Compare the two ratings:
ratings_diff = abs(merged_df['rating_y'] - merged_df['rating_x'])
ratings_diff = list(ratings_diff)
ratings_diff
# Out:
# [0.020000000000000018,
#  0.010000000000000231,
#  0.0,
#  0.0099999999999997868,
#  0.020000000000000462,
#  0.010000000000000231,
#  0.020000000000000462,
#  0.0,
#  0.0099999999999997868,
#  0.020000000000000018,
#  0.0099999999999997868,
#  0.019999999999999574,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.020000000000000018,
#  0.0099999999999997868,
#  0.0,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.019999999999999574,
#  0.0,
#  0.0099999999999997868,
#  0.010000000000000231,
#  0.010000000000000231,
#  0.020000000000000018,
#  0.069999999999999396,
#  0.0099999999999997868,
#  0.010000000000000231,
#  0.010000000000000231,
#  0.010000000000000231,
#  0.020000000000000018,
#  0.0099999999999997868,
#  0.029999999999999805,
#  0.020000000000000018,
#  0.0,
#  0.0099999999999997868,
#  0.010000000000000675,
#  0.029999999999999805,
#  0.020000000000000018,
#  0.010000000000000231,
#  0.020000000000000018,
#  0.020000000000000462,
#  0.020000000000000018,
#  0.0,
#  0.010000000000000675,
#  0.0,
#  0.25,
#  0.0099999999999997868,
#  0.13999999999999968,
#  0.020000000000000018,
#  0.020000000000000462,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.020000000000000018,
#  0.0,
#  0.0,
#  0.040000000000000036,
#  0.019999999999999574,
#  0.0099999999999997868,
#  0.019999999999999574,
#  0.010000000000000675,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.020000000000000462,
#  0.019999999999999574,
#  0.0,
#  0.0,
#  0.0099999999999997868,
#  0.040000000000000036,
#  0.030000000000000249,
#  0.0099999999999997868,
#  0.0099999999999997868,
#  0.010000000000000231,
#  0.0099999999999997868,
#  0.010000000000000231,
#  0.0099999999999997868]

# %%
plt.scatter(np.arange(len(ratings_diff)), ratings_diff)
plt.title('Absolute difference in Kaggle vs recently scrapped GoodReads ratings')
plt.xlabel('Book Index')
plt.ylabel('Absolute difference in ratings')
plt.savefig("../Plots/kaggle_vs_our_ratings_diff.png", bbox_inches='tight')
plt.show()

# %%
# The ratings do not appear to have changed much from Kaggle's dataset and our more recent scrapped ratings!
